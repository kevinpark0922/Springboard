# %% [markdown]
# This exercise will require you to pull some data from the Qunadl API. Qaundl is currently the most widely used aggregator of financial market data.

# %% [markdown]
# As a first step, you will need to register a free account on the http://www.quandl.com website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:

# %%
# Store the API key as a string - according to PEP8, constants are always named in all upper case
API_KEY = '7G5B1k9xRmAzT424pEyu'

# %% [markdown]
# Qaundl has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Quandl API instructions here: https://docs.quandl.com/docs/time-series

# %% [markdown]
# While there is a dedicated Python package for connecting to the Quandl API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
#!pip install quandl
# First, import the relevant modules
import quandl
import pandas as pd 
import json

# %%
# Now, call the Quandl API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned
data = quandl.get("FSE/AFX_X", start_date="2017-1-1", end_date="2017-12-31")
#data = quandl.get_table('FSE/AFX_X', date = { 'gte': '2017-1-1', 'lte': '2017-12-31' })
data_dict = data.to_dict() 
print(type(data_dict))
# Out:
# <class 'dict'>
#              Open   High    Low  Close  Change  Traded Volume    Turnover  \
# Date
# 2017-01-02  34.99  35.94  34.99  35.80     NaN        44700.0   1590561.0
# 2017-01-03  35.90  35.93  35.34  35.48     NaN        70618.0   2515473.0
# 2017-01-04  35.48  35.51  34.75  35.19     NaN        54408.0   1906810.0
# 2017-01-05  35.02  35.20  34.73  35.06     NaN        48412.0   1692326.0
# 2017-01-06  34.91  35.21  34.91  35.04     NaN        27507.0    964046.0
# 2017-01-09  35.29  35.35  34.43  34.67     NaN        62225.0   2157182.0
# 2017-01-10  34.80  34.98  34.46  34.91     NaN        43976.0   1528055.0
# 2017-01-11  34.95  36.00  34.84  35.42     NaN       123530.0   4369079.0
# 2017-01-12  35.38  35.38  34.31  34.90     NaN       163860.0   5703427.0
# 2017-01-13  34.98  34.98  34.60  34.85     NaN        59367.0   2065534.0
# 2017-01-16  34.85  35.24  34.56  35.07     NaN        47879.0   1678679.0
# ...

# %%
print(type(data.index[1]))
# Out:
# <class 'pandas._libs.tslib.Timestamp'>

# %%
print(type(data['Open'].max()))

print(data['Open'].max())
print(data['Open'].min())

for index, row in data.iterrows():
    if( row['Open'] == data['Open'].max()):
        print("Max open price %.2f at %s" % (row['Open'], index))
    if( row['Open'] == data['Open'].min()):
        print("Min open price %.2f at %s" % (row['Open'], index))
# Out:
# <class 'numpy.float64'>
# 53.11
# 34.0
# Min open price 34.00 at 2017-01-24 00:00:00
# Max open price 53.11 at 2017-12-14 00:00:00

# %%
max_highest_lowest = (data['High'] - data['Low']).max()
min_highest_lowest = (data['High'] - data['Low']).min()


print(type(max_highest_lowest))
print(min_highest_lowest)

for index, row in data.iterrows():
    if((row['High'] - row['Low']) == max_highest_lowest):
        print(" the largest change in any one day %.2f at %s" % (max_highest_lowest, index))
    if((row['High'] - row['Low']) == min_highest_lowest):
        print(" the smallest change in any one day %.2f at %s" % (min_highest_lowest, index))
# Out:
# <class 'numpy.float64'>
# 0.19
#  the largest change in any one day 2.81 at 2017-05-11 00:00:00
#  the smallest change in any one day 0.19 at 2017-09-08 00:00:00

# %%
for index, row in data.iterrows():
     print("Close price %.2f at %s" % (row['Close'], index))
# Out:
# Close price 35.80 at 2017-01-02 00:00:00
# Close price 35.48 at 2017-01-03 00:00:00
# Close price 35.19 at 2017-01-04 00:00:00
# Close price 35.06 at 2017-01-05 00:00:00
# Close price 35.04 at 2017-01-06 00:00:00
# Close price 34.67 at 2017-01-09 00:00:00
# Close price 34.91 at 2017-01-10 00:00:00
# Close price 35.42 at 2017-01-11 00:00:00
# Close price 34.90 at 2017-01-12 00:00:00
# Close price 34.85 at 2017-01-13 00:00:00
# Close price 35.07 at 2017-01-16 00:00:00
# Close price 34.99 at 2017-01-17 00:00:00
# Close price 34.90 at 2017-01-18 00:00:00
# Close price 34.50 at 2017-01-19 00:00:00
# Close price 34.17 at 2017-01-20 00:00:00
# Close price 34.06 at 2017-01-23 00:00:00
# Close price 34.22 at 2017-01-24 00:00:00
# Close price 34.83 at 2017-01-25 00:00:00
# Close price 34.89 at 2017-01-26 00:00:00
# Close price 35.30 at 2017-01-27 00:00:00
# Close price 35.15 at 2017-01-30 00:00:00
# Close price 34.56 at 2017-01-31 00:00:00
# Close price 35.94 at 2017-02-01 00:00:00
# ...

# %%
next_data = data.iloc[0:]
#print(next_data[0])
large_change_two_days = 0
large_change_date = 0
count1 = 0
count2 = 1
for index, row in data.iterrows():
    if len(data.index) > count1 and len(data.index) > count2:
        if count1 == 0:
            large_change_two_days = data.iloc[count2]['Close'] - data.iloc[count1]['Close']
        else:
            if(large_change_two_days > (data.iloc[count2]['Close'] - data.iloc[count1]['Close'])):
                print("keep the previous diff pre large_change_two_days %.2f and new change %.2f" %(large_change_two_days,(data.iloc[count2]['Close'] - data.iloc[count1]['Close'])))
            else:
                print("found large chnage pre large_change_two_days %.2f and new change %.2f" %(large_change_two_days,(data.iloc[count2]['Close'] - data.iloc[count1]['Close'])))
                large_change_two_days = data.iloc[count2]['Close'] - data.iloc[count1]['Close']
                large_change_date = index
    #print(data.iloc[count2]['Close'] - data.iloc[count1]['Close'])
    count1 = count1 + 1
    count2 = count2 + 1
# Out:
# found large chnage pre large_change_two_days -0.32 and new change -0.29
# found large chnage pre large_change_two_days -0.29 and new change -0.13
# found large chnage pre large_change_two_days -0.13 and new change -0.02
# keep the previous diff pre large_change_two_days -0.02 and new change -0.37
# found large chnage pre large_change_two_days -0.02 and new change 0.24
# found large chnage pre large_change_two_days 0.24 and new change 0.51
# keep the previous diff pre large_change_two_days 0.51 and new change -0.52
# keep the previous diff pre large_change_two_days 0.51 and new change -0.05
# keep the previous diff pre large_change_two_days 0.51 and new change 0.22
# keep the previous diff pre large_change_two_days 0.51 and new change -0.08
# keep the previous diff pre large_change_two_days 0.51 and new change -0.09
# keep the previous diff pre large_change_two_days 0.51 and new change -0.40
# keep the previous diff pre large_change_two_days 0.51 and new change -0.33
# ...

# %%
#print(pd.DateOffset(1))
#print(large_change_date + pd.Timedelta(days=1))

print("largest change %.2f between %s and %s" %(large_change_two_days,large_change_date,large_change_date + pd.Timedelta(days=1)))
# Out:
# largest change 1.72 between 2017-05-10 00:00:00 and 2017-05-11 00:00:00

# %%
sumofall = data.sum(axis = 0, skipna = True) 
print(sumofall['Traded Volume']/len(data.index))
# Out:
# 89124.3372549

# %% [markdown]
# These are your tasks for this mini project:
#
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
# 2. Convert the returned JSON object into a Python dictionary.
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.
# 4. What was the largest change in any one day (based on High and Low price)?
# 5. What was the largest change between any two days (based on Closing Price)?
# 6. What was the average daily trading volume during this year?
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)
