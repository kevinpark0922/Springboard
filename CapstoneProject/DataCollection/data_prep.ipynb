# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\parkkev\\pdf_image_dir\\scripts'

# %%
path = 'C:\\Users\\parkkev\\pdf_image_dir\\scripts\\bs.txt'
bs_file = open(path,'r')
#for line in bs_file:
#    print(line)
 
import os

for files in os.walk('C:\\Users\\parkkev\\pdf_image_dir\\'):
    print(files)
# Out:
# ('C:\\Users\\parkkev\\pdf_image_dir\\', ['scripts'], ['0000000035_jet_financial_covenant_09302015_prelim_1.jpg', '0000000070_2015_year_end_and_dscr_1.jpg', '0000000070_2015_year_end_and_dscr_2.jpg', '0000000070_2015_year_end_and_dscr_3.jpg', '0000000091_financials_internal_12-31-2105_1.jpg', '0000000091_financials_internal_12-31-2105_2.jpg', '0000000091_financials_internal_12-31-2105_3.jpg', '0000000092_community_bridge_2016_financial_report_compilation_03_31_16_1.jpg', '0000000092_community_bridge_2016_financial_report_compilation_03_31_16_10.jpg', '0000000092_community_bridge_2016_financial_report_compilation_03_31_16_11.jpg', '0000000092_community_bridge_2016_financial_report_compilation_03_31_16_12.jpg', '0000000092_community_bridge_2016_financial_report_compilation_03_31_16_13.jpg', '0000000092_community_bridge_2016_financial_report_compilation_03_31_16_14.jpg', '0000000092_community_bridge_2016_financial_report_compilation_03_31_16_15.jpg', '0000000092_community_bridge_2016_fin
# ...

# %%
import glob
import shutil
import os

src_dir = "your/source/dir"
dst_dir = "C:\\Users\\parkkev\\pdf_image_dir\\scripts\\BalanceSheet"

path = 'C:/Users/parkkev/springboard_project/scripts/none.txt'
none_file = open(path,'r')

for line in none_file:
    print(line.rstrip())
    shutil.copy(line.rstrip(), 'C:/Users/parkkev/springboard_project/scripts/None') 
    


#for f in bs_file:
    #for files in os.walk('C:\\Users\\parkkev\\pdf_image_dir\\'):
#    print('C:\\Users\\parkkev\\pdf_image_dir\\' + f)
#    shutil.copy2('C:\\Users\\parkkev\\pdf_image_dir\\' + f, 'C:\\Users\\parkkev\\pdf_image_dir\\scripts\\BalanceSheet')
# Out:
# C:/Users/parkkev/pdf_image_dir/1-fabuwood_financial_statements_12.31.16_1.jpg
# C:/Users/parkkev/pdf_image_dir/1-fabuwood_financial_statements_12.31.16_2.jpg
# C:/Users/parkkev/pdf_image_dir/1-fabuwood_financial_statements_12.31.16_3.jpg
# C:/Users/parkkev/pdf_image_dir/1-fabuwood_financial_statements_12.31.16_9.jpg
# C:/Users/parkkev/pdf_image_dir/1-fabuwood_financial_statements_12.31.16_10.jpg
# C:/Users/parkkev/pdf_image_dir/1-fabuwood_financial_statements_12.31.16_11.jpg
# C:/Users/parkkev/pdf_image_dir/02_rls_final_audited_financial_statements_as_of_06-30-17_1.jpg
# C:/Users/parkkev/pdf_image_dir/02_rls_final_audited_financial_statements_as_of_06-30-17_2.jpg
# C:/Users/parkkev/pdf_image_dir/02_rls_final_audited_financial_statements_as_of_06-30-17_3.jpg
# C:/Users/parkkev/pdf_image_dir/02_rls_final_audited_financial_statements_as_of_06-30-17_4.jpg
# C:/Users/parkkev/pdf_image_dir/02_rls_final_audited_financial_statements_as_of_06-30-17_10.jpg
# ...
